# %%
import pandas as pd

# %%
patient = pd.DataFrame(columns=['id', 'sex', 'birth_year', 'country', 'region',
                                'infection_reason', 'infection_order', 'contact_number',
                                'confirmed_date', 'released_date', 'state'])

# %%
patient.loc[0] = [1, 'female', 1984, 'China', 'filtered at airport', 'visit to Wuhan', 1, 45, '2020-01-20', '2020-02-06', 'released']
patient.loc[1] = [2, 'male', 1964, 'Korea', 'filtered at airport', 'visit to Wuhan', 1, 75, '2020-01-24', '2020-02-05','released']
patient.loc[2] = [3, 'male', 1966, 'Korea', 'capital area', 'visit to Wuhan', 1, 16, '2020-01-26', '2020-02-12','released']
patient.loc[3] = [4, 'male', 1964, 'Korea', 'capital area', 'visit to Wuhan', 1, 95, '2020-01-27', '2020-02-09','released']
patient.loc[4] = [5, 'male', 1987, 'Korea', 'capital area', 'visit to Wuhan', 1, 31, '2020-01-30', None,'isolated']
patient.loc[5] = [6, 'male', 1964, 'Korea', 'capital area', 'contact with 3rd patient', 2, 17, '2020-01-30', '2020-02-19','released']
patient.loc[6] = [7, 'male', 1991, 'Korea', 'capital area', 'visit to Wuhan', 1, 9, '2020-01-30', '2020-02-15','released']
patient.loc[7] = [8, 'female', 1957, 'Korea', 'Jeollabuk-do', 'visit to Wuhan', 1, 113, '2020-01-31', '2020-02-12','released']
patient.loc[8] = [9, 'female', 1992, 'Korea', 'capital area', 'contact with 5th patient', 2, 2, '2020-01-31', '2020-02-24','released']
patient.loc[9] = [10, 'female', 1966, 'Korea', 'capital area', 'contact with 6th patient', 3, 43, '2020-01-31', '2020-02-19','released']
patient.loc[10] = [11, 'male', 1995, 'Korea', 'capital area', 'contact with 6th patient', 3, 0, '2020-01-31', '2020-02-10','released']
patient.loc[11] = [12, 'male', 1971, 'China', 'capital area', 'contact with patient in Japan', 2, 422, '2020-02-01', '2020-02-18','released']
patient.loc[12] = [13, 'male', 1992, 'Korea', 'filtered at airport', 'residence in Wuhan', 1, 0, '2020-02-02', '2020-02-24','released']
patient.loc[13] = [14, 'female', 1980, 'China', 'capital area', 'contact with 12th patient', 3, 3, '2020-02-02', '2020-02-18','released']
patient.loc[14] = [15, 'male', 1977, 'Korea', 'capital area', 'contact with 4th patient', 2, 15, '2020-02-02', '2020-02-24','released']
patient.loc[15] = [16, 'female', 1977, 'Korea', 'Gwangju', 'visit to Thailand', 1, 450, '2020-02-04', '2020-02-19','released']
patient.loc[16] = [17, 'male', 1982, 'Korea', 'capital area', 'contact with patient in Singapore', 2, 290, '2020-02-05', '2020-02-12','released']
patient.loc[17] = [18, 'female', 1999, 'Korea', 'Gwangju', 'contact with 16th patient', 2, 8, '2020-02-05', '2020-02-19','released']
patient.loc[18] = [19, 'male', 1983, 'Korea', 'capital area', 'contact with patient in Singapore', 2, 68, '2020-02-05', '2020-02-21','released']
patient.loc[19] = [20, 'female', 1978, 'Korea', 'capital area', 'contact with 15th patient', 3, 2, '2020-02-05', '2020-02-24','released']
patient.loc[20] = [21, 'female', 1960, 'Korea', 'capital area', 'contact with 6th patient', 3, 6, '2020-02-05', None,'isolated']
patient.loc[21] = [22, 'male', 1973, 'Korea', 'Gwangju', 'contact with 16th patient', 2, 1, '2020-02-06', '2020-02-15','released']
patient.loc[22] = [23, 'female', 1962, 'China', 'capital area', 'visit to Wuhan', 1, 23, '2020-02-06', None,'isolated']
patient.loc[23] = [24, 'male', 1992, 'Korea', 'filtered at airport', 'residence in Wuhan', 1, 0, '2020-02-06', None,'isolated']
patient.loc[24] = [25, 'female', 1946, 'Korea', 'capital area', 'contact with 27th patient', 2, 12, '2020-02-09', '2020-02-22','released']
patient.loc[25] = [26, 'male', 1968, 'Korea', 'capital area', 'visit to China', 1, 0, '2020-02-09', None,'isolated']
patient.loc[26] = [27, 'female', 1982, 'China', 'capital area', 'visit to China', 1, 40, '2020-02-09', None,'isolated']
patient.loc[27] = [28, 'female', 1989, 'China', 'capital area', 'contact with 3rd patient', 2, 1, '2020-02-10', '2020-02-17','released']
patient.loc[28] = [29, 'male', 1938, 'Korea', 'capital area', None, None, 117, '2020-02-16', None,'isolated']
patient.loc[29] = [30, 'female', 1952, 'Korea', 'capital area', None, None, 27, '2020-02-16', None,'isolated']

# 2/18
patient.loc[30] = [31, 'female', 1959, 'Korea', 'Daegu', None, None, 1160, '2020-02-18', None,'isolated']
patient.loc[31] = [32, 'female', 2009, 'Korea', 'capital area', None, None, None, '2020-02-18', None,'isolated']
patient.loc[32] = [33, 'female', 1980, 'Korea', 'Daegu', None, None, None, '2020-02-18', None,'isolated']
patient.loc[33] = [34, 'male', 1996, 'Korea', 'Daegu', None, None, None, '2020-02-18', None,'isolated']
patient.loc[34] = [35, 'female', 1994, 'Korea', 'Daegu', None, None, None, '2020-02-18', None,'isolated']
patient.loc[35] = [36, 'female', 1972, 'Korea', 'Daegu', None, None, None, '2020-02-18', None,'isolated']
patient.loc[36] = [37, 'female', 1973, 'Korea', 'Gyeongsangbuk-do', None, None, None, '2020-02-18', None,'isolated']
patient.loc[37] = [38, 'female', 1963, 'Korea', 'Daegu', None, None, None, '2020-02-18', None,'deceased']
patient.loc[38] = [39, 'female', 1959, 'Korea', 'Gyeongsangbuk-do', None, None, None, '2020-02-18', None,'isolated']

# 2/19
patient.loc[39] = [40, 'male', 1943, 'Korea', 'capital area', None, None, 8, '2020-02-19', None,'isolated']
patient.loc[40] = [41, 'female', 1951, 'Korea', 'Gyeongsangbuk-do', None, None, None, '2020-02-19', None,'isolated']
patient.loc[41] = [42, 'female', 1991, 'Korea', 'Daegu', None, None, None, '2020-02-19', None,'isolated']
patient.loc[42] = [43, 'female', 1962, 'Korea', 'Daegu', None, None, None, '2020-02-19', None,'isolated']
patient.loc[43] = [44, 'female', 1974, 'Korea', 'Daegu', None, None, None, '2020-02-19', None,'isolated']
patient.loc[44] = [45, 'female', 1966, 'Korea', 'Daegu', None, None, None, '2020-02-19', None,'isolated']
patient.loc[45] = [46, 'male', 1992, 'Korea', 'Daegu', None, None, None, '2020-02-19', None,'isolated']
patient.loc[46] = [47, 'female', 1957, 'Korea', 'Daegu', 'contact with 31th patient', None, None, '2020-02-19', None,'isolated']
patient.loc[47] = [48, 'female', 1948, 'Korea', 'Daegu', 'contact with 31th patient', None, None, '2020-02-19', None,'isolated']
patient.loc[48] = [49, 'male', 1962, 'Korea', 'Daegu', 'contact with 31th patient', None, None, '2020-02-19', None,'isolated']
patient.loc[49] = [50, 'male', 1944, 'Korea', 'Daegu', 'contact with 31th patient', None, None, '2020-02-19', None,'isolated']
patient.loc[50] = [51, 'female', 1959, 'Korea', 'Daegu', 'contact with 31th patient', None, None, '2020-02-19', None,'isolated']
patient.loc[51] = [52, 'male', 1996, 'Korea', None, None, None, None, '2020-02-19', None,'isolated']
patient.loc[52] = [53, 'female', 1982, 'Korea', 'Daegu', None, None, None, '2020-02-19', None,'isolated']
patient.loc[53] = [54, 'male', 1963, 'Korea', 'Gyeongsangbuk-do', None, None, None, '2020-02-19', None,'deceased']
patient.loc[54] = [55, 'male', 1961, 'Korea', 'Gyeongsangbuk-do', None, None, None, '2020-02-19', None,'deceased']
patient.loc[55] = [56, 'male', 1945, 'Korea', 'capital area', None, None, None, '2020-02-19', None,'isolated']
patient.loc[56] = [57, 'male', 1990, 'Korea', None, None, None, None, '2020-02-19', None,'isolated']
patient.loc[57] = [58, 'female', 1994, 'Korea', None, None, None, None, '2020-02-19', None,'isolated']
patient.loc[58] = [59, 'female', 1986, 'Korea', None, None, None, None, '2020-02-19', None,'isolated']
patient.loc[59] = [60, 'female', 1961, 'Korea', None, None, None, None, '2020-02-19', None,'isolated']
patient.loc[60] = [61, 'female', 1962, 'Korea', None, None, None, None, '2020-02-19', None,'isolated']
patient.loc[61] = [62, 'male', 1960, 'Korea', None, None, None, None, '2020-02-19', None,'isolated']
patient.loc[62] = [63, 'female', 1968, 'Korea', None, None, None, None, '2020-02-20', None,'isolated']
patient.loc[63] = [64, 'female', 1961, 'Korea', None, None, None, None, '2020-02-19', None,'isolated']
patient.loc[64] = [65, 'female', 1970, 'Korea', 'Daegu', None, None, None, '2020-02-19', None,'isolated']
patient.loc[65] = [66, 'male', 1998, 'Korea', None, None, None, None, '2020-02-19', None,'isolated']

# 2/20
patient.loc[66] = [67, 'female', 1990, 'Korea', None, None, None, None, '2020-02-20', None,'isolated']
patient.loc[67] = [68, 'female', 1964, 'Korea', None, None, None, None, '2020-02-20', None,'isolated']
patient.loc[68] = [69, 'male', 1991, 'Korea', None, None, None, None, '2020-02-20', None,'isolated']
patient.loc[69] = [70, 'female', 1972, 'Korea', None, None, None, None, '2020-02-20', None,'isolated']
patient.loc[70] = [71, 'female', 1964, 'Korea', None, None, None, None, '2020-02-20', None,'isolated']
patient.loc[71] = [72, 'female', 1981, 'Korea', None, None, None, None, '2020-02-20', None,'isolated']
patient.loc[72] = [73, 'female', 2000, 'Korea', None, None, None, None, '2020-02-20', None,'isolated']
patient.loc[73] = [74, 'male', 1971, 'Korea', None, None, None, None, '2020-02-20', None,'isolated']
patient.loc[74] = [75, 'female', 1997, 'Korea', None, None, None, None, '2020-02-20', None,'isolated']
patient.loc[75] = [76, 'male', 1984, 'Korea', None, None, None, None, '2020-02-20', None,'isolated']
patient.loc[76] = [77, 'female', 1963, 'Korea', None, None, None, None, '2020-02-20', None,'isolated']
patient.loc[77] = [78, 'male', 1965, 'Korea', None, None, None, None, '2020-02-20', None,'isolated']
patient.loc[78] = [79, 'female', 1998, 'Korea', None, None, None, None, '2020-02-20', None,'isolated']
patient.loc[79] = [80, 'female', 1986, 'Korea', None, None, None, None, '2020-02-20', None,'isolated']
patient.loc[80] = [81, 'female', 1955, 'Korea', None, None, None, None, '2020-02-20', None,'isolated']
patient.loc[81] = [82, 'male', 1956, 'Korea', None, None, None, None, '2020-02-20', None,'isolated']

# %%
# 2/20
for i in range(82,104):
    patient.loc[i] = [i+1, None, None, 'Korea', None, None, None, None, '2020-02-20', None,'isolated']

# 2/21
for i in range(104,204):
    if i == 106:
        patient.loc[i] = [i+1, 'male', 1953, 'Korea', None, None, None, None, '2020-02-21', None,'deceased']
    else:
        patient.loc[i] = [i+1, None, None, 'Korea', None, None, None, None, '2020-02-21', None,'isolated']

# 2/22
for i in range(204,433):
    if i == 285:
        patient.loc[i] = [i+1, 'male', 1958, 'Korea', None, None, None, None, '2020-02-22', None,'deceased']
    elif i == 297:
        patient.loc[i] = [i+1, 'male', 1962, 'Korea', None, None, None, None, '2020-02-22', None,'deceased']
    else:
        patient.loc[i] = [i+1, None, None, 'Korea', None, None, None, None, '2020-02-22', None,'isolated']
    
# 2/23
for i in range(433,602):
    if i == 442:
        patient.loc[i] = [i+1, 'male', 1979, 'Korea', None, None, None, None, '2020-02-23', None,'deceased']
    else:
        patient.loc[i] = [i+1, None, None, 'Korea', None, None, None, None, '2020-02-23', None,'isolated']
    
# 2/24
for i in range(602,833):
    patient.loc[i] = [i+1, None, None, 'Korea', None, None, None, None, '2020-02-24', None,'isolated']
    
# 2/25
for i in range(833,977):
    if i == 924:
        patient.loc[i] = [i+1, 'female', 1951, 'Korea', None, None, None, None, '2020-02-25', None,'deceased']
    else:
        patient.loc[i] = [i+1, None, None, 'Korea', None, None, None, None, '2020-02-25', None,'isolated']

# %%
patient.to_csv('patient.csv', index=False)
